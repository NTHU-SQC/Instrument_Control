# %%
import os
import sys
import pprint as pp
import numpy as np
import matplotlib.pyplot as plt

# set the main directory to import qel instruments drivers
sys.path.append(os.getcwd().replace('\\documents\\measure_notebooks',''))
from instruments.Tektronix_AWG5208.TektronixAWG_core import Tektronix_AWG5208
from instruments.Tektronix_AWG5208.TektronixAWG_sequenceEditor import Time_Domain_Sequence
from instruments.Tektronix_AWG5208.plot_tools import *

# %%
rbs =  Time_Domain_Sequence()

# define the initial condition for generating a rabi-sequence


wfm_amount = 201
wfm_totlen = 10000*3
gauss_sig = 100
gauss_delta_flat = 1
qubitDrive_mkrDuration = 0
qubitDrive_mkr = 'no_mkr'

readOut_offset = 7000*3
readOut_flat = 3000
readOut_mkrDuration = 1000
readOut_mkr = 'mkr1'

# clean the temporary buffer
store_rabi_seq = {}

# set the initial condition for generating a rabi-sequence
store_rabi_seq = rbs.gen_Rabi_seq(wfm_amount,
                                wfm_totlen,
                                gauss_sig,
                                gauss_delta_flat,
                                qubitDrive_mkrDuration,
                                qubitDrive_mkr,
                                readOut_offset,
                                readOut_flat,
                                readOut_mkrDuration,
                                readOut_mkr)

# display the sequence stored structure
pp.pprint(store_rabi_seq)

# plot the pulse shaping in the specified step
seq_name = 'Rabi_sequence'
step_select = 2
store_time_domain_seq = store_rabi_seq
plt_qb_rd(seq_name, step_select, store_time_domain_seq)
# Out:
# {'QubitDrive': {1: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_1_GaussFlat_0pnts'},
#                 2: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_2_GaussFlat_1pnts'},
#                 3: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_3_GaussFlat_2pnts'},
#                 4: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_4_GaussFlat_3pnts'},
#                 5: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_5_GaussFlat_4pnts'},
#                 6: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_6_GaussFlat_5pnts'},
#                 7: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_7_GaussFlat_6pnts'},
#                 8: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_8_GaussFlat_7pnts'},
#                 9: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'mkr_tone': 'no_mkr',
#                     'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                     'wfm_name': 'QubitDrive_Rabi_Index_9_GaussFlat_8pnts'},
#                 10: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_10_GaussFlat_9pnts'},
#                 11: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_11_GaussFlat_10pnts'},
#                 12: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_12_GaussFlat_11pnts'},
#                 13: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_13_GaussFlat_12pnts'},
#                 14: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_14_GaussFlat_13pnts'},
#                 15: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_15_GaussFlat_14pnts'},
#                 16: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_16_GaussFlat_15pnts'},
#                 17: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_17_GaussFlat_16pnts'},
#                 18: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_18_GaussFlat_17pnts'},
#                 19: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_19_GaussFlat_18pnts'},
#                 20: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_20_GaussFlat_19pnts'},
#                 21: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_21_GaussFlat_20pnts'},
#                 22: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_22_GaussFlat_21pnts'},
#                 23: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_23_GaussFlat_22pnts'},
#                 24: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_24_GaussFlat_23pnts'},
#                 25: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_25_GaussFlat_24pnts'},
#                 26: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_26_GaussFlat_25pnts'},
#                 27: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_27_GaussFlat_26pnts'},
#                 28: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_28_GaussFlat_27pnts'},
#                 29: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_29_GaussFlat_28pnts'},
#                 30: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index_30_GaussFlat_29pnts'},
#                 31: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'mkr_tone': 'no_mkr',
#                      'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                      'wfm_name': 'QubitDrive_Rabi_Index
{'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_170_GaussFlat_3000pnts'},
#              171: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_171_GaussFlat_3000pnts'},
#              172: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_172_GaussFlat_3000pnts'},
#              173: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_173_GaussFlat_3000pnts'},
#              174: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_174_GaussFlat_3000pnts'},
#              175: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_175_GaussFlat_3000pnts'},
#              176: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_176_GaussFlat_3000pnts'},
#              177: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_177_GaussFlat_3000pnts'},
#              178: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_178_GaussFlat_3000pnts'},
#              179: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_179_GaussFlat_3000pnts'},
#              180: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_180_GaussFlat_3000pnts'},
#              181: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_181_GaussFlat_3000pnts'},
#              182: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_182_GaussFlat_3000pnts'},
#              183: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_183_GaussFlat_3000pnts'},
#              184: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_184_GaussFlat_3000pnts'},
#              185: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_185_GaussFlat_3000pnts'},
#              186: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_186_GaussFlat_3000pnts'},
#              187: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_187_GaussFlat_3000pnts'},
#              188: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_188_GaussFlat_3000pnts'},
#              189: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_189_GaussFlat_3000pnts'},
#              190: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_190_GaussFlat_3000pnts'},
#              191: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_191_GaussFlat_3000pnts'},
#              192: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_192_GaussFlat_3000pnts'},
#              193: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_193_GaussFlat_3000pnts'},
#              194: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_194_GaussFlat_3000pnts'},
#              195: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_195_GaussFlat_3000pnts'},
#              196: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_196_GaussFlat_3000pnts'},
#              197: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_197_GaussFlat_3000pnts'},
#              198: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_198_GaussFlat_3000pnts'},
#              199: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_199_GaussFlat_3000pnts'},
#              200: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_200_GaussFlat_3000pnts'},
#              201: {'mkrData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'mkr_tone': 'mkr1',
#                    'wfmData': array([0., 0., 0., ..., 0., 0., 0.]),
#                    'wfm_name': 'ReadOut_Rabi_Index_201_GaussFlat_3000pnts'}}}

# %%
# pp.pprint(store_rabi_seq)

# %%
inst_name = 'Tektronix_AWG5208'
inst_address = 'TCPIP0::192.168.20.43::inst0::INSTR'
timeout = 10
Clean_Option = True
sample_rate = 1E9
ref_ext = 10E6

# initialize AWG settings
awgClient = Tektronix_AWG5208(inst_name, inst_address, timeout)
awgClient.connect()
if Clean_Option:awgClient.del_wlist();awgClient.del_slist()
awgClient.set_channel_mkr(0,1,0,1,0,0,0,0)
awgClient.set_sample_rate(sample_rate)
awgClient.set_extref_source(ref_ext)
# Out:
# Connect to Tektronix_AWG5208 successfully
# Statement: TEKTRONIX,AWG5208,B030598,FV:6.6.0131.0

# %%
seq_name = 'Rabi_Sequence'
track_assign_order = list(store_time_domain_seq.keys())

awgClient.set_sequential_assign_wfm2seqtable(
    seq_name,
    track_assign_order,
    store_time_domain_seq)
# Out:
# The transfer mission is completed.

# %%
channel_qb = 1
seq_track_for_qubitDrive = 1
channel_rd = 2
seq_track_for_readOut = 2
awgClient.load_seq_to_channel(channel_qb, seq_name, seq_track_for_qubitDrive)
awgClient.load_seq_to_channel(channel_rd, seq_name, seq_track_for_readOut)

# %%
# disconnect the awg
awgClient.disconnect()
# Out:
# Tektronix_AWG5208 has been disconnected by user.
